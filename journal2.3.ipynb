# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import random

# %%
x = np.random.rand(1000)

# %%
plt.hist(x, bins=100)
plt.xlabel("length of fish scale")
plt.ylabel("how many scales of that length")
plt.savefig("fish_hist.jpg"
# Out:
# Text(0, 0.5, 'how many scales of that length')
